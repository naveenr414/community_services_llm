# %%
import requests
import csv
from bs4 import BeautifulSoup
import pandas as pd

# %%
URL = "https://headsup-pa.org/referraltool/"  

response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")

rows = soup.find_all("div", class_="table-row body-row")

csv_filename = "EPINET_resource.csv"
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["County", "Resource Type", "Organization", "Website", "Phone", "Address"])

    for row in rows: 
        county = row.get("county", "").strip()
        resource_type = row.get("resource-type", "").strip()
        organization = row.find("div", class_="organization").text.strip() if row.find("div", class_="organization") else ""
        
        website_div = row.find("div", class_="website")
        website = website_div.find("a")["href"] if website_div and website_div.find("a") else ""
        
        phone = row.find("div", class_="phone").text.strip() if row.find("div", class_="phone") else ""
        address = row.find("div", class_="address").text.strip() if row.find("div", class_="address") else ""

        writer.writerow([county, resource_type, organization, website, phone, address])

# %%
df = pd.read_csv('EPINET_resource.csv')
df
# Out:
#             County                Resource Type                  Organization  \
# 0         Lycoming                     FEP Site                      CSG EPIC
# 1        Allegheny                     FEP Site              ENGAGE Allegheny
# 2     Westmoreland                     FEP Site           ENGAGE Westmoreland
# 3           Monroe                     FEP Site            HOPE Carbon/Monroe
# 4          Luzerne                     FEP Site          HOPE Luzerne/Wyoming
# ...            ...                          ...                           ...
# 2251     Allegheny       Community Organization  412 Youth Zone Mental Health
# 2252        Beaver  Private Psychiatry Practice  A & A Psychological Services
# 2253  Philadelphia       Community Organization                 A Home Within
# 2254        Centre       Community Organization              A Journey To You
# 2255   Northampton       Community Organization          ABA Support Services
#
#                                                 Website  \
# 0               https://csgonline.org/csg-williamsport/
# 1                                         www.wfspa.org
# 2                                         www.wfspa.org
# 3                                         www.cscwv.org
# 4                                         www.cscwv.org
# ...                                                 ...
# 2251  https://www.alleghenycounty.us/Human-Services/...
# 2252                https://aapsychological.weebly.com/
# 2253                       https://www.ahomewithin.org/
# 2254                          https://ajourneytoyou.com
# 2255                    https://abasupportservices.com/
#
#                         Phone  \
# 0              (877) 907-7970
# 1              (412) 694-6142
# 2              (724) 335-9883
# 3     (877) 433-5112 Ext: 758
# 4              (570) 825-6425
# ...                       ...
# 2251                      NaN
# 2252           (724) 561-6382
# 2253           (888) 898-2249
# 2254           (814) 325-0280
# 2255           (610) 365-8373
#
#                                                 Address
# 0       1000 Commerce Park Dr#110Williamsport, PA 17701
# 1                     221 Penn AveWilkinsburg, PA 15221
# 2               1045 4th AvenueNew Kensington, PA 15068
# 3                      912 Main StStroudsburg, PA 18360
# 4       335 South Franklin StreetWilkes-Barre, PA 18702
# ...                                                 ...
# 2251                304 Wood StreetPittsburgh, PA 15222
# 2252      250 Insurance StreetSuite 202Beaver, PA 15009
# 2253  1528 Walnut StreetSuite 1706Philadelphia, PA 1...
# 2254          1107 W College AveState College, PA 16801
# 2255               224 Nazareth PikeBethlemem, PA 18020
#
# [2256 rows x 6 columns]
